# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
meta_file = 'raw_data/metadata.csv'
meta_df = pd.read_csv(meta_file)
meta_df.columns.tolist()
# Out:
# /Users/tujingxuan/anaconda3/envs/cosi132a/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ['cord_uid',
#  'sha',
#  'source_x',
#  'title',
#  'doi',
#  'pmcid',
#  'pubmed_id',
#  'license',
#  'abstract',
#  'publish_time',
#  'authors',
#  'journal',
#  'Microsoft Academic Paper ID',
#  'WHO #Covidence',
#  'has_pdf_parse',
#  'has_pmc_xml_parse',
#  'full_text_file',
#  'url']

# %%
meta_df = meta_df.dropna(subset=['pubmed_id', 'sha']).reset_index(drop=True)
meta_pmids = np.array(meta_df['pubmed_id'].values, dtype='int').tolist()
meta_pmids = set([str(i) for i in meta_pmids])
len(meta_pmids)
# Out:
# 26475

# %%
chem_gene_ixns_relation = 'raw_data/KG/chem_gene_ixns_relation.csv'
chem_df = pd.read_csv(chem_gene_ixns_relation, delimiter='\t')
chem_df
# Out:
#         ChemicalID  GeneID           Organism  OrganismID  \
# 0          C534883    4149                NaN         NaN
# 1          C534883    4149                NaN         NaN
# 2          C534883    4609       Homo sapiens      9606.0
# 3          C534883    4609       Homo sapiens      9606.0
# 4          C534883    4609       Homo sapiens      9606.0
# ...            ...     ...                ...         ...
# 1506528    C424422    6548  Rattus norvegicus     10116.0
# 1506529    C424422    6548                NaN         NaN
# 1506530    C424422    6548                NaN         NaN
# 1506531    C424422    6774  Rattus norvegicus     10116.0
# 1506532    C424422    6774  Rattus norvegicus     10116.0
#
#                                                Interaction  \
# 0        10074-G5 affects the folding of and results in...
# 1        10074-G5 inhibits the reaction [MYC protein bi...
# 2        10074-G5 analog results in decreased expressio...
# 3        10074-G5 results in decreased activity of MYC ...
# 4        10074-G5 results in decreased expression of MY...
# ...                                                    ...
# 1506528  zoniporide results in decreased activity of SL...
# 1506529  zoniporide binds to and results in decreased a...
# 1506530  zoniporide results in decreased activity of SL...
# 1506531  stattic inhibits the reaction [zoniporide resu...
# 1506532  zoniporide results in increased phosphorylatio...
#
#                                         InteractionActions  \
# 0        affects^binding|affects^folding|decreases^acti...
# 1                       affects^binding|decreases^reaction
# 2                                     decreases^expression
# 3                                       decreases^activity
# 4                                     decreases^expression
# ...                                                    ...
# 1506528                                 decreases^activity
# 1506529                 affects^binding|decreases^activity
# 1506530                                 decreases^activity
# 1506531       decreases^reaction|increases^phosphorylation
# 1506532                          increases^phosphorylation
#
#                                                      pmids
# 0                                                 26474287
# 1                                                 26474287
# 2                                                 26036281
# 3                                                 25716159
# 4                                                 26036281
# ...                                                    ...
# 1506528                                           15037516
# 1506529                                           17356886
# 1506530  11259552|11277524|12215493|12595915|14724181|1...
# 1506531                                           20942815
# 1506532                                           20942815
#
# [1506533 rows x 7 columns]

# %%
chem_pmids = set(chem_df.pmids.tolist())
chem_pmids & meta_pmids
# Out:
# {'17288598',
#  '17434272',
#  '19409407',
#  '19772353',
#  '20003521',
#  '23825585',
#  '24244327',
#  '24534281',
#  '24561310',
#  '25966753',
#  '26551751',
#  '26752173',
#  '26917416',
#  '27760801',
#  '28438630',
#  '28786057',
#  '28806546',
#  '29038090'}

# %%
actions = chem_df.InteractionActions.tolist()

# %%
fst_act = []
snd_act = []
for act in actions:
    acts = act.split('|')
    for a in acts:
        a = a.split('^')
    fst_act.append(a[0])
    snd_act.append(a[1])

# %%
print(Counter(fst_act))
print(Counter(snd_act))
# Out:
# Counter({'increases': 826981, 'decreases': 511880, 'affects': 167672})
# Counter({'expression': 1130849, 'reaction': 117645, 'methylation': 62487, 'activity': 50199, 'phosphorylation': 33143, 'response to substance': 28648, 'secretion': 19346, 'abundance': 8445, 'cleavage': 7567, 'chemical synthesis': 5576, 'metabolic processing': 5442, 'uptake': 5123, 'binding': 4795, 'localization': 4596, 'splicing': 4169, 'transport': 3931, 'degradation': 2304, 'oxidation': 2058, 'mutagenesis': 1549, 'reduction': 1299, 'glucuronidation': 841, 'stability': 820, 'hydroxylation': 808, 'export': 806, 'hydrolysis': 714, 'acetylation': 679, 'import': 674, 'ubiquitination': 400, 'cotreatment': 383, 'sulfation': 320, 'folding': 207, 'glutathionylation': 190, 'nitrosation': 96, 'sumoylation': 73, 'ADP-ribosylation': 46, 'lipidation': 46, 'prenylation': 38, 'alkylation': 33, 'O-linked glycosylation': 30, 'glycosylation': 29, 'carboxylation': 21, 'glycation': 19, 'amination': 18, 'ethylation': 13, 'farnesylation': 12, 'N-linked glycosylation': 12, 'acylation': 9, 'carbamoylation': 8, 'ribosylation': 6, 'palmitoylation': 6, 'geranoylation': 5})

# %%
if len(chem_df[chem_df.pmids == 'wedc']):
    print(len(chem_df[chem_df.pmids == 'wec']))

# %%
chem_pmids = chem_df.pmids.values
chem_pmids = [int(i.split('|')[0]) for i in chem_pmids]
chem_pmids

# %%
chem_df.columns.tolist()
# Out:
# ['ChemicalID',
#  'GeneID',
#  'Organism',
#  'OrganismID',
#  'Interaction',
#  'InteractionActions',
#  'pmids']

# %%
Counter(chem_df.Organism.dropna().tolist()).most_common()
# Out:
# [('Homo sapiens', 666388),
#  ('Mus musculus', 377907),
#  ('Rattus norvegicus', 297256),
#  ('Danio rerio', 60317),
#  ('Oryctolagus cuniculus', 11477),
#  ('Caenorhabditis elegans', 9635),
#  ('Gallus gallus', 6504),
#  ('Bos taurus', 5001),
#  ('Drosophila melanogaster', 4732),
#  ('Xenopus tropicalis', 4512),
#  ('Pimephales promelas', 4085),
#  ('Sus scrofa', 3968),
#  ('Macaca fascicularis', 3909),
#  ('Xenopus laevis', 3045),
#  ('Macaca mulatta', 2285),
#  ('Platichthys flesus', 1866),
#  ('Oncorhynchus mykiss', 1837),
#  ('Ovis aries', 1671),
#  ('Mesocricetus auratus', 1609),
#  ('Canis lupus familiaris', 1189),
#  ('Cricetulus griseus', 935),
#  ('Micropterus salmoides', 795),
#  ('Cavia porcellus', 786),
#  ('Mizuhopecten yessoensis', 709),
#  ('Cyprinus carpio', 631),
#  ('Gobiocypris rarus', 596),
#  ('Oryzias latipes', 590),
#  ('Daphnia magna', 551),
#  ('Mytilus galloprovincialis', 484),
#  ('Oikopleura dioica', 466),
#  ('Perca flavescens', 443),
#  ('Salmo salar', 419),
#  ('Rattus', 370),
#  ('Cavia', 316),
#  ('Folsomia candida', 296),
#  ('Fundulus grandis', 268),
#  ('Mus spretus', 254),
#  ('Equus caballus', 237),
#  ('Tachysurus fulvidraco', 227),
#  ('Aedes aegypti', 218),
#  ('Carassius auratus', 214),
#  ('Sparus aurata', 210),
#  ('Felis catus', 194),
#  ('Chrysemys picta bellii', 191),
#  ('Meriones unguiculatus', 186),
#  ('Mammalia', 166),
#  ('Peromyscus californicus', 163),
#  ('Rodentia', 154),
#  ('Salmo trutta', 153),
#  ('Crassostrea gigas', 152),
#  ('Fundulus heteroclitus', 150),
#  ('Lumbricus rubellus', 149),
#  ('Clarias batrachus', 147),
#  ('Chlorocebus aethiops', 146),
#  ('Tursiops truncatus', 143),
#  ('Oncorhynchus kisutch', 126),
#  ('Cricetinae', 121),
#  ('Electrophorus electricus', 115),
#  ('Oreochromis niloticus', 108),
#  ('Strongylocentrotus purpuratus', 101),
#  ('Capra hircus', 97),
#  ('Musca domestica', 97),
#  ('Mustela putorius furo', 89),
#  ('Poeciliopsis lucida', 85),
#  ('Scophthalmus maximus', 83),
#  ('Tigriopus japonicus', 81),
#  ('Gadus morhua', 79),
#  ('Eisenia fetida', 78),
#  ('Pan troglodytes', 75),
#  ('Kryptolebias marmoratus', 74),
#  ('Coturnix japonica', 73),
#  ('Dicentrarchus labrax', 73),
#  ('Apis mellifera', 73),
#  ('Solea senegalensis', 72),
#  ('Acanthogobius hasta', 72),
#  ('Lithobates catesbeianus', 71),
#  ('Oreochromis aureus x Oreochromis niloticus', 71),
#  ('Paracentrotus lividus', 68),
#  ('Hypomesus transpacificus', 68),
#  ('Chironomus riparius', 67),
#  ('Oryzias melastigma', 66),
#  ('Biomphalaria glabrata', 65),
#  ('Anopheles gambiae', 65),
#  ('Homo', 58),
#  ("Cyprinus carpio 'jian'", 56),
#  ('Anguilla anguilla', 54),
#  ('Ursus maritimus', 53),
#  ('Meleagris gallopavo', 53),
#  ('Micropogonias undulatus', 51),
#  ('Setaria cervi', 49),
#  ('Pelophylax nigromaculatus', 49),
#  ('Mytilus edulis', 48),
#  ('Oryzias javanicus', 47),
#  ('Ictalurus punctatus', 46),
#  ('Ctenopharyngodon idella', 46),
#  ('Chironomus tentans', 45),
#  ('Dreissena polymorpha', 43),
#  ('Alligator mississippiensis', 43),
#  ('Didelphidae', 42),
#  ('Pseudopleuronectes americanus', 40),
#  ('Crassostrea angulata', 39),
#  ('Salvelinus alpinus', 38),
#  ('Lumbriculus variegatus', 38),
#  ('Squalus acanthias', 36),
#  ('Acanthopagrus schlegelii', 36),
#  ('Bombyx mori', 36),
#  ('Gasterosteus aculeatus', 35),
#  ('Ciona intestinalis', 34),
#  ('Papio', 33),
#  ('Columbidae', 31),
#  ('Ruditapes philippinarum', 31),
#  ('Saccostrea glomerata', 30),
#  ('Anas platyrhynchos', 29),
#  ('Palaemon pugio', 29),
#  ('Tetraodon', 28),
#  ('Colinus virginianus', 28),
#  ('Mugil cephalus', 27),
#  ('Didelphis virginiana', 26),
#  ('Gobius niger', 26),
#  ('Tetronarce californica', 25),
#  ('Periplaneta americana', 24),
#  ('Bubalus bubalis', 24),
#  ('Cottus gobio', 24),
#  ('Drosophila simulans', 23),
#  ('Anolis carolinensis', 23),
#  ('Locusta migratoria', 23),
#  ('Cyprinodon variegatus', 23),
#  ('Torpedo marmorata', 23),
#  ('Mustela', 23),
#  ('Chilo suppressalis', 23),
#  ('Thalassoma pavo', 23),
#  ('Macaca radiata', 23),
#  ('Callithrix jacchus', 22),
#  ('Rana pipiens', 22),
#  ('Pelophylax ridibundus', 22),
#  ('Phalacrocorax carbo', 21),
#  ('Callinectes sapidus', 21),
#  ('Pagrus major', 21),
#  ('Plecoglossus altivelis', 21),
#  ('Solenopsis invicta', 21),
#  ('Penaeus chinensis', 21),
#  ('Pangasianodon hypophthalmus', 21),
#  ('Rutilus rutilus', 20),
#  ('Sebastiscus marmoratus', 20),
#  ('Phasianidae', 19),
#  ('Murinae', 19),
#  ('Perinereis nuntia', 19),
#  ('Penaeus vannamei', 18),
#  ('Pusa sibirica', 18),
#  ('Sparidae', 18),
#  ('Gymnogyps californianus', 18),
#  ('Corbicula fluminea', 18),
#  ('Bursaphelenchus xylophilus', 18),
#  ('Larus argentatus', 17),
#  ('Oncorhynchus tshawytscha', 17),
#  ('Macaca', 17),
#  ('Hyriopsis cumingii', 17),
#  ('Longpotamon honanense', 16),
#  ('Chlorocebus sabaeus', 16),
#  ('Enchytraeus albidus', 16),
#  ('Columba livia', 16),
#  ('Gambusia holbrooki', 16),
#  ('Psammomys obesus', 16),
#  ('Aves', 16),
#  ('Rhipicephalus microplus', 15),
#  ('Helicoverpa armigera', 15),
#  ('Labeo catla', 15),
#  ('Labeo rohita', 15),
#  ('Carassius gibelio', 15),
#  ('Anopheles stephensi', 15),
#  ('Gerbillinae', 14),
#  ('Blattella germanica', 14),
#  ('Apolygus lucorum', 14),
#  ('unidentified monkey', 13),
#  ('Myodes glareolus', 13),
#  ('marmosets', 13),
#  ('Channa punctata', 13),
#  ('unclassified Rodentia', 13),
#  ('Aphis gossypii', 13),
#  ('Pseudodiaptomus annandalei', 13),
#  ('Neovison vison', 12),
#  ('Oreochromis mossambicus', 12),
#  ('Heteropneustes fossilis', 12),
#  ('Fundulus lima', 12),
#  ('Lumbricus terrestris', 12),
#  ('Lithognathus mormyrus', 12),
#  ('Coturnix coturnix', 12),
#  ('Morone americana', 12),
#  ('Brachionus koreanus', 11),
#  ('Lucilia cuprina', 11),
#  ('Rattus rattus', 11),
#  ('Boreogadus saida', 11),
#  ('Pleuronectes platessa', 11),
#  ('Hexaplex trunculus', 11),
#  ('Daphnia pulex', 11),
#  ('Hypophthalmichthys nobilis', 11),
#  ('Larus hyperboreus', 11),
#  ('Jaculus orientalis', 10),
#  ('Lepomis macrochirus', 10),
#  ('Gallotia galloti', 10),
#  ('Trichinella nativa', 10),
#  ('Brugia malayi', 10),
#  ('Trematomus bernacchii', 10),
#  ('Leucoraja erinacea', 10),
#  ('Caiman latirostris', 10),
#  ('Erythrocebus patas', 10),
#  ('Saccostrea cucullata', 10),
#  ('Piaractus mesopotamicus', 10),
#  ('Phalangeridae', 10),
#  ('Hypophthalmichthys molitrix', 10),
#  ('Delphinapterus leucas', 9),
#  ('Microgadus tomcod', 9),
#  ('Oryziinae', 9),
#  ('Clarias gariepinus', 9),
#  ('Azumapecten farreri', 9),
#  ('Takifugu obscurus', 9),
#  ('Culex pipiens', 9),
#  ('Orbicella franksi', 9),
#  ('Argopecten purpuratus', 9),
#  ('Macaca nemestrina', 9),
#  ('Pseudacris regilla', 9),
#  ('Saimiri sciureus', 8),
#  ('Onychostoma barbatulum', 8),
#  ('Poecilia reticulata', 8),
#  ('Aphanius iberus', 8),
#  ('Chelon saliens', 8),
#  ('Anguilla japonica', 8),
#  ('Laeonereis acuta', 8),
#  ('Mytilus trossulus', 8),
#  ('Chironomus tepperi', 8),
#  ('Eriocheir sinensis', 8),
#  ('Culex pipiens pallens', 8),
#  ('Rhinella arenarum', 8),
#  ('Phasianus colchicus', 7),
#  ('Coturnix', 7),
#  ('Ctenocephalides felis', 7),
#  ('Capra', 7),
#  ('Microtus ochrogaster', 7),
#  ('Taeniopygia guttata', 7),
#  ('Echinococcus granulosus', 7),
#  ('Melanotaenia fluviatilis', 7),
#  ('Crassostrea virginica', 7),
#  ('Lagenorhynchus acutus', 7),
#  ('Xeropicta derbentina', 7),
#  ('Callitrichinae', 7),
#  ('Mustelidae', 7),
#  ('Lagopus lagopus scotica', 7),
#  ('Artemia', 7),
#  ('Sus', 6),
#  ('Chelydra serpentina', 6),
#  ('Columbiformes', 6),
#  ('Poecilia vivipara', 6),
#  ('Cynops orientalis', 6),
#  ('Orchesella cincta', 6),
#  ('Xenopodinae', 6),
#  ('Pediculus humanus corporis', 6),
#  ('Tilapia', 6),
#  ('Oncorhynchus mykiss gairdneri', 6),
#  ('Hydra vulgaris', 6),
#  ('Apis cerana cerana', 6),
#  ('Rana temporaria', 6),
#  ('Abramis brama', 6),
#  ('Serranidae', 6),
#  ('Hemidactylus flaviviridis', 6),
#  ('Cynoglossus semilaevis', 6),
#  ('Arctica islandica', 6),
#  ('Branchiostoma floridae', 6),
#  ('Macrobrachium rosenbergii', 6),
#  ('Jenynsia multidentata', 5),
#  ('Labeo', 5),
#  ('Anopheles albimanus', 5),
#  ('Hyalella azteca', 5),
#  ('Squalius cephalus', 5),
#  ('Bovinae', 5),
#  ('Phoca vitulina', 5),
#  ('Barbus graellsii', 5),
#  ('Gambusia affinis', 5),
#  ('Haliotis diversicolor supertexta', 5),
#  ('Physella acuta', 5),
#  ('Phoxinus keumkang', 5),
#  ('Oxya chinensis', 5),
#  ('Pediculus humanus capitis', 5),
#  ('Pocillopora damicornis', 5),
#  ('Exorista sorbillans', 5),
#  ('Sapajus apella', 5),
#  ('Anopheles sinensis', 5),
#  ('Anopheles arabiensis', 5),
#  ('Andrias japonicus', 5),
#  ('Bathymodiolus azoricus', 5),
#  ('Girardinichthys viviparus', 5),
#  ('Salamandridae', 5),
#  ('Ambystoma mexicanum', 5),
#  ('Asterias rubens', 4),
#  ('Schistosoma haematobium', 4),
#  ('Schistosoma mansoni', 4),
#  ('Ovis aries musimon', 4),
#  ('Macaca fuscata', 4),
#  ('Ovis', 4),
#  ('Rhamdia quelen', 4),
#  ('Odontophoridae', 4),
#  ('Chelon labrosus', 4),
#  ('Nannopterum auritus', 4),
#  ('Oplegnathus fasciatus', 4),
#  ('Polypheretima elongata', 4),
#  ('Paralichthys olivaceus', 4),
#  ('Cydia pomonella', 4),
#  ('Colossoma macropomum', 4),
#  ('Mystus vittatus', 4),
#  ("Carassius auratus ssp. 'Pengze'", 4),
#  ('Camelus', 4),
#  ('Perca fluviatilis', 4),
#  ('Thunnus maccoyii', 4),
#  ('Aphis glycines', 4),
#  ('Myzus persicae', 4),
#  ('Nilaparvata lugens', 4),
#  ('Sus scrofa domesticus', 4),
#  ('Manduca sexta', 4),
#  ('Gyps fulvus', 4),
#  ('Perna viridis', 4),
#  ('Cirrhinus cirrhosus', 4),
#  ('Eisenia andrei', 4),
#  ('Phodopus sungorus', 4),
#  ('Nannospalax galili', 4),
#  ('Nannospalax judaei', 4),
#  ('Sebastes schlegelii', 4),
#  ('Proechimys guyannensis', 4),
#  ('Phoca largha', 4),
#  ('Rugosa rugosa', 4),
#  ('Musculus', 3),
#  ('Mya arenaria', 3),
#  ('Oncorhynchus gilae apache', 3),
#  ('Leptuca pugilator', 3),
#  ('Arvicolinae', 3),
#  ('Pygoscelis adeliae', 3),
#  ('Schistosoma bovis', 3),
#  ('Dugesia japonica', 3),
#  ('Phlebotomus papatasi', 3),
#  ('Achatina fulica', 3),
#  ('Vertebrata', 3),
#  ('Lepidoptera', 3),
#  ('Chamelea gallina', 3),
#  ('Coturnix coturnix coturnix', 3),
#  ('Haemonchus contortus', 3),
#  ('Solen grandis', 3),
#  ('Acipenser transmontanus', 3),
#  ('Blarina brevicauda', 3),
#  ('Microtus agrestis', 3),
#  ('Charybdis japonica', 3),
#  ('Pleurodeles waltl', 3),
#  ('Carassius cuvieri', 3),
#  ('Octopus vulgaris', 3),
#  ('Metaphire posthuma', 3),
#  ('Spodoptera exigua', 3),
#  ('Bungarus', 3),
#  ('Trichoplusia ni', 3),
#  ('Trachemys scripta', 3),
#  ('Schistosoma japonicum', 3),
#  ('Coregonus lavaretus', 3),
#  ('Tribolium castaneum', 3),
#  ('Hoplias malabaricus', 3),
#  ('Anopheles funestus', 3),
#  ('Testudo graeca nabeulensis', 3),
#  ('Sturnus vulgaris', 3),
#  ('Ameiurus nebulosus', 3),
#  ('Peromyscus leucopus', 3),
#  ('Plutella xylostella', 3),
#  ('Calanus finmarchicus', 3),
#  ('Porcellio dilatatus', 3),
#  ('Rana sylvatica', 3),
#  ('Tetranychus urticae', 3),
#  ('Trichinella spiralis', 3),
#  ('Physeter catodon', 3),
#  ('Urva javanica', 3),
#  ('Seriola lalandi', 3),
#  ('Electrophorus', 3),
#  ('Galleria mellonella', 3),
#  ('Homarus americanus', 3),
#  ('Papio sp.', 3),
#  ('Heliothis virescens', 3),
#  ('Brachionus calyciflorus', 3),
#  ('Aplysia californica', 3),
#  ('Nauphoeta cinerea', 3),
#  ('Mus musculus domesticus', 3),
#  ('Sepia officinalis', 2),
#  ('Primates', 2),
#  ('Acipenser brevirostrum', 2),
#  ('Acipenser oxyrinchus oxyrinchus', 2),
#  ('Boaedon fuliginosus', 2),
#  ('Bombina orientalis', 2),
#  ('Sterna hirundo', 2),
#  ('Blattodea', 2),
#  ('Rhinella marina', 2),
#  ('Taenia solium', 2),
#  ('Anabas testudineus', 2),
#  ('Monopterus albus', 2),
#  ('Cherax destructor', 2),
#  ('Lates calcarifer', 2),
#  ('Anguilla rostrata', 2),
#  ('Canis', 2),
#  ('Paracyclopina nana', 2),
#  ('Oryzias', 2),
#  ('Porcellio scaber', 2),
#  ('Coris julis', 2),
#  ('Cerastoderma edule', 2),
#  ('Podarcis siculus', 2),
#  ('Anas', 2),
#  ('Mamestra brassicae', 2),
#  ('Boleophthalmus pectinirostris', 2),
#  ('Mactra quadrangularis', 2),
#  ('Petromyzon marinus', 2),
#  ('Xyrauchen texanus', 2),
#  ('Daphnia sp.', 2),
#  ('Bactrocera dorsalis', 2),
#  ('Microtus oeconomus', 2),
#  ('Ochotona curzoniae', 2),
#  ('Pomatoschistus microps', 2),
#  ('Palaemon elegans', 2),
#  ('Papio ursinus', 2),
#  ('Chinchilla chinchilla', 2),
#  ('Halichoerus grypus', 2),
#  ('Pusa hispida', 2),
#  ('Lucilia sericata', 2),
#  ('Alburnus alburnus', 2),
#  ('Ballerus ballerus', 2),
#  ('Blicca bjoerkna', 2),
#  ('Cotesia vestalis', 2),
#  ('Diaeretiella rapae', 2),
#  ('Frankliniella occidentalis', 2),
#  ('Leuciscus idus', 2),
#  ('unclassified Felidae', 2),
#  ('Chorthippus brunneus', 2),
#  ('Lampetra fluviatilis', 2),
#  ('Heterotremata', 2),
#  ('Panulirus interruptus', 2),
#  ('Sphaerechinus granularis', 2),
#  ('Trichinella pseudospiralis', 2),
#  ('unidentified dogfish', 2),
#  ('Fundulus', 2),
#  ('Bombus ignitus', 2),
#  ('Bemisia tabaci', 2),
#  ('Atrachya menetriesi', 2),
#  ('Massylaea vermiculata', 2),
#  ('Onchocerca volvulus', 2),
#  ('Cricetinae gen. sp.', 2),
#  ('Euphlyctis cyanophlyctis', 2),
#  ('Artiodactyla', 2),
#  ('Bos indicus x Bos taurus', 2),
#  ('Ambystoma maculatum', 2),
#  ('Aplysia kurodai', 2),
#  ('Orbicella faveolata', 2),
#  ('Silurus meridionalis', 2),
#  ('Ardea herodias', 2),
#  ('Suncus murinus', 1),
#  ('Cambarellus montezumae', 1),
#  ('Girardinichthys multiradiatus', 1),
#  ('Planorbidae', 1),
#  ('Oncorhynchus clarkii henshawi', 1),
#  ('Crassostrea hongkongensis', 1),
#  ('Hynobius leechii', 1),
#  ('Onychodactylus fischeri', 1),
#  ('Peromyscus maniculatus', 1),
#  ('Pelophylax esculentus', 1),
#  ('Andrias davidianus', 1),
#  ('Sesamia nonagrioides', 1),
#  ('Gammarus fossarum', 1),
#  ('Cebus capucinus', 1),
#  ('Enchytraeus buchholzi', 1),
#  ('Ruditapes decussatus', 1),
#  ('Polypterus senegalus', 1),
#  ('Collembola', 1),
#  ('Metapenaeus', 1),
#  ('Pediculus humanus', 1),
#  ('Chinchilla', 1),
#  ('Sigmodon hispidus', 1),
#  ('Unio tumidus', 1),
#  ('Spodoptera frugiperda', 1),
#  ('Takifugu rubripes', 1),
#  ('Tubifex tubifex', 1),
#  ('Penaeus indicus', 1),
#  ('Antechinus stuartii', 1),
#  ('Carassius carassius', 1),
#  ('Sarotherodon melanotheron', 1),
#  ('Macoma nasuta', 1),
#  ('Coregonus albula', 1),
#  ('Esox lucius', 1),
#  ('Macrobrachium lamarrei', 1),
#  ('Sander lucioperca', 1),
#  ('Cochliomyia hominivorax', 1),
#  ('Hypothenemus hampei', 1),
#  ('Macrophthalmus japonicus', 1),
#  ('Agelena labyrinthica', 1),
#  ('Pardosa lugubris', 1),
#  ('Siganus canaliculatus', 1),
#  ('Rangifer tarandus', 1),
#  ('Syncerus', 1),
#  ('Cirrhinus mrigala', 1),
#  ('Thalassoma bifasciatum', 1),
#  ('Nucella lapillus', 1),
#  ('Carangoides', 1),
#  ('Plectropomus maculatus', 1),
#  ('Clonorchis sinensis', 1),
#  ('Struthio camelus', 1),
#  ('Trachemys scripta elegans', 1),
#  ('Caligus rogercresseyi', 1),
#  ('Parascaris equorum', 1),
#  ('Bubo', 1),
#  ('Epinephelus awoara', 1),
#  ('Ceratitis capitata', 1),
#  ('Chelon auratus', 1),
#  ('Isonychia', 1),
#  ('Scrobicularia plana', 1),
#  ('Cimex lectularius', 1),
#  ('Harmonia axyridis', 1),
#  ('Tribolium confusum', 1),
#  ('Vespula maculifrons', 1),
#  ('Microtus pinetorum', 1),
#  ('Anguilla', 1),
#  ('Rajiformes', 1),
#  ('Hemicentrotus pulcherrimus', 1),
#  ('Scylla serrata', 1),
#  ('Helix aspersa', 1),
#  ('Cyanistes caeruleus', 1),
#  ('Parus major', 1),
#  ('Channa striata', 1),
#  ('Cynoscion nebulosus', 1),
#  ('Lytechinus anamesus', 1),
#  ('Nippostrongylus brasiliensis', 1),
#  ('Hediste diversicolor', 1),
#  ('Callithrix', 1),
#  ('Brycon cephalus', 1),
#  ('Neohelice granulata', 1),
#  ('Loxosceles laeta', 1),
#  ('Salvelinus namaycush', 1),
#  ('Macridiscus veneriformis', 1),
#  ('Eumetopias jubatus', 1),
#  ('Phocoenoides dalli', 1),
#  ('Hynobius retardatus', 1),
#  ('Teleostei', 1)]

# %%
Counter(chem_df.InteractionActions.dropna().tolist()).most_common()
# Out:
# [('increases^expression', 355860),
#  ('decreases^expression', 306895),
#  ('affects^cotreatment|increases^expression', 126038),
#  ('affects^expression', 106669),
#  ('affects^cotreatment|decreases^expression', 94185),
#  ('decreases^reaction|increases^expression', 73907),
#  ('increases^methylation', 25286),
#  ('decreases^expression|decreases^reaction', 22067),
#  ('decreases^methylation', 18192),
#  ('increases^expression|increases^reaction', 15711),
#  ('affects^cotreatment|decreases^reaction|increases^expression', 12398),
#  ('decreases^reaction|increases^phosphorylation', 12253),
#  ('decreases^reaction|increases^activity', 11433),
#  ('affects^methylation', 11432),
#  ('decreases^activity', 10638),
#  ('affects^binding|increases^reaction', 10246),
#  ('increases^activity', 9488),
#  ('affects^reaction|increases^expression', 9391),
#  ('affects^cotreatment|affects^expression', 9381),
#  ('affects^response to substance', 6952),
#  ('decreases^reaction|increases^secretion', 6023),
#  ('affects^expression|decreases^reaction', 5944),
#  ('increases^phosphorylation', 5587),
#  ('affects^binding|increases^expression', 5215),
#  ('affects^binding|decreases^reaction', 4901),
#  ('affects^binding|decreases^expression', 4649),
#  ('affects^binding', 4624),
#  ('decreases^expression|increases^reaction', 4603),
#  ('affects^cotreatment|increases^chemical synthesis|increases^expression',
#   4275),
#  ('affects^expression|affects^response to substance', 4246),
#  ('decreases^response to substance', 4183),
#  ('decreases^activity|decreases^reaction', 4109),
#  ('affects^cotreatment|affects^expression|affects^reaction', 3924),
#  ('affects^reaction|decreases^expression', 3487),
#  ('decreases^reaction|increases^expression|increases^reaction', 3426),
#  ('increases^response to substance', 3378),
#  ('affects^splicing', 3376),
#  ('affects^cotreatment|decreases^methylation', 3359),
#  ('affects^cotreatment|decreases^expression|increases^chemical synthesis',
#   3312),
#  ('affects^expression|affects^reaction', 3189),
#  ('affects^binding|decreases^expression|increases^activity', 3031),
#  ('affects^cotreatment|increases^methylation', 2929),
#  ('affects^cotreatment|decreases^expression|decreases^reaction', 2907),
#  ('increases^secretion', 2888),
#  ('affects^binding|increases^activity|increases^expression', 2661),
#  ('decreases^reaction|increases^uptake', 2647),
#  ('affects^binding|decreases^reaction|increases^reaction', 2624),
#  ('decreases^phosphorylation', 2598),
#  ('affects^binding|increases^activity', 2567),
#  ('affects^localization|decreases^reaction', 2531),
#  ('decreases^reaction|increases^cleavage', 2486),
#  ('affects^localization', 2349),
#  ('decreases^reaction|increases^activity|increases^phosphorylation', 2262),
#  ('affects^cotreatment|increases^expression|increases^reaction', 2109),
#  ('increases^abundance|increases^expression', 2093),
#  ('affects^binding|decreases^activity', 1972),
#  ('increases^activity|increases^reaction', 1935),
#  ('decreases^reaction|increases^abundance', 1810),
#  ('affects^cotreatment|increases^activity', 1808),
#  ('increases^cleavage', 1669),
#  ('increases^expression|increases^response to substance', 1644),
#  ('decreases^phosphorylation|decreases^reaction', 1575),
#  ('increases^metabolic processing', 1561),
#  ('affects^binding|decreases^reaction|increases^activity', 1522),
#  ('increases^activity|increases^expression', 1505),
#  ('affects^cotreatment|increases^phosphorylation', 1480),
#  ('affects^cotreatment|decreases^reaction|increases^phosphorylation', 1458),
#  ('increases^phosphorylation|increases^reaction', 1371),
#  ('affects^cotreatment|decreases^reaction|increases^activity', 1364),
#  ('affects^expression|increases^reaction', 1355),
#  ('increases^mutagenesis', 1343),
#  ('decreases^expression|increases^abundance', 1316),
#  ('decreases^reaction|increases^transport', 1245),
#  ('decreases^expression|increases^response to substance', 1197),
#  ('increases^activity|increases^phosphorylation', 1164),
#  ('affects^metabolic processing', 1163),
#  ('decreases^secretion', 1104),
#  ('affects^cotreatment|decreases^reaction|increases^secretion', 1088),
#  ('increases^abundance', 1085),
#  ('affects^activity', 986),
#  ('increases^reaction|increases^secretion', 985),
#  ('decreases^reaction|increases^degradation', 981),
#  ('affects^response to substance|increases^expression', 875),
#  ('increases^cleavage|increases^reaction', 872),
#  ('affects^cotreatment|affects^methylation', 870),
#  ('decreases^reaction|increases^activity|increases^expression', 851),
#  ('affects^cotreatment|decreases^activity', 822),
#  ('affects^cotreatment|increases^secretion', 777),
#  ('increases^oxidation', 771),
#  ('affects^cotreatment|decreases^reaction|increases^expression|increases^reaction',
#   765),
#  ('affects^reaction|increases^phosphorylation', 755),
#  ('affects^cotreatment|affects^reaction|increases^expression', 732),
#  ('affects^cotreatment|affects^response to substance', 724),
#  ('affects^cotreatment|increases^cleavage', 719),
#  ('affects^response to substance|decreases^expression', 716),
#  ('decreases^reaction|increases^metabolic processing', 691),
#  ('increases^uptake', 687),
#  ('increases^glucuronidation', 678),
#  ('increases^transport', 675),
#  ('affects^reaction|decreases^reaction|increases^expression', 669),
#  ('affects^cotreatment|decreases^reaction|increases^abundance', 659),
#  ('affects^binding|increases^activity|increases^reaction', 657),
#  ('affects^expression|affects^splicing', 637),
#  ('decreases^reaction|increases^abundance|increases^expression', 613),
#  ('decreases^activity|increases^reaction', 605),
#  ('decreases^reaction|increases^phosphorylation|increases^reaction', 605),
#  ('affects^reaction|increases^activity', 596),
#  ('decreases^reaction|decreases^response to substance', 592),
#  ('affects^abundance', 590),
#  ('decreases^reaction|increases^expression|increases^secretion', 586),
#  ('affects^reaction|increases^secretion', 585),
#  ('decreases^reaction|increases^activity|increases^reaction', 581),
#  ('affects^cotreatment|decreases^expression|increases^reaction', 559),
#  ('increases^chemical synthesis', 541),
#  ('increases^activity|increases^cleavage', 532),
#  ('decreases^reaction|increases^activity|increases^cleavage', 527),
#  ('decreases^expression|decreases^reaction|increases^reaction', 523),
#  ('increases^abundance|increases^reaction', 520),
#  ('affects^cotreatment|decreases^response to substance', 519),
#  ('affects^binding|affects^cotreatment|increases^reaction', 516),
#  ('affects^cotreatment|decreases^activity|decreases^reaction', 513),
#  ('increases^expression|increases^secretion', 511),
#  ('affects^secretion', 508),
#  ('affects^cotreatment|increases^abundance', 501),
#  ('decreases^reaction|increases^chemical synthesis', 497),
#  ('decreases^reaction|increases^reaction|increases^secretion', 471),
#  ('decreases^reaction|increases^localization', 470),
#  ('affects^binding|affects^reaction', 465),
#  ('decreases^reaction|increases^response to substance', 462),
#  ('affects^binding|decreases^reaction|increases^expression', 461),
#  ('increases^degradation', 459),
#  ('affects^cotreatment|decreases^phosphorylation', 459),
#  ('decreases^activity|decreases^expression', 456),
#  ('affects^cotreatment|increases^response to substance', 448),
#  ('affects^binding|increases^expression|increases^reaction', 421),
#  ('affects^transport', 419),
#  ('decreases^reaction|decreases^secretion', 411),
#  ('decreases^abundance', 403),
#  ('affects^cotreatment|decreases^reaction|increases^cleavage', 397),
#  ('affects^cotreatment|affects^localization', 396),
#  ('decreases^reaction|increases^oxidation', 390),
#  ('decreases^activity|decreases^phosphorylation', 362),
#  ('increases^expression|increases^phosphorylation', 354),
#  ('affects^localization|increases^expression', 351),
#  ('decreases^phosphorylation|increases^reaction', 349),
#  ('decreases^reaction|increases^import', 349),
#  ('affects^cotreatment|increases^abundance|increases^expression', 348),
#  ('decreases^reaction|increases^export', 346),
#  ('affects^cotreatment|decreases^methylation|increases^expression', 346),
#  ('affects^binding|decreases^activity|decreases^reaction', 343),
#  ('increases^chemical synthesis|increases^metabolic processing', 331),
#  ('increases^activity|increases^phosphorylation|increases^reaction', 328),
#  ('increases^abundance|increases^activity', 323),
#  ('decreases^reaction|increases^chemical synthesis|increases^expression', 322),
#  ('affects^phosphorylation', 318),
#  ('decreases^response to substance|increases^expression', 305),
#  ('increases^reaction|increases^uptake', 294),
#  ('affects^cotreatment|affects^expression|affects^response to substance', 294),
#  ('affects^reaction|increases^cleavage', 291),
#  ('increases^hydroxylation', 290),
#  ('decreases^reaction|increases^abundance|increases^activity', 289),
#  ('affects^cotreatment|affects^response to substance|increases^expression',
#   289),
#  ('decreases^reaction|increases^abundance|increases^reaction', 288),
#  ('decreases^activity|decreases^response to substance', 286),
#  ('decreases^reaction|increases^hydrolysis', 284),
#  ('increases^hydrolysis', 284),
#  ('increases^reduction', 281),
#  ('increases^localization', 281),
#  ('decreases^reaction|increases^cleavage|increases^reaction', 279),
#  ('decreases^reaction|increases^hydroxylation', 276),
#  ('affects^cotreatment|affects^localization|decreases^reaction', 262),
#  ('affects^localization|increases^reaction', 261),
#  ('affects^binding|affects^cotreatment|decreases^reaction', 256),
#  ('decreases^reaction|increases^expression|increases^phosphorylation', 247),
#  ('increases^acetylation', 239),
#  ('affects^reaction|increases^abundance', 236),
#  ('affects^binding|affects^reaction|increases^reaction', 236),
#  ('affects^binding|affects^cotreatment|decreases^reaction|increases^reaction',
#   235),
#  ('affects^transport|decreases^reaction', 235),
#  ('affects^cotreatment|increases^reaction|increases^secretion', 232),
#  ('affects^cotreatment|increases^activity|increases^reaction', 231),
#  ('affects^binding|increases^abundance|increases^activity', 231),
#  ('affects^reaction|decreases^expression|decreases^reaction', 231),
#  ('decreases^reaction|increases^reduction', 229),
#  ('increases^reaction|increases^transport', 228),
#  ('affects^reaction|increases^expression|increases^reaction', 224),
#  ('affects^localization|affects^reaction', 224),
#  ('affects^cotreatment|increases^phosphorylation|increases^reaction', 222),
#  ('decreases^activity|decreases^reaction|increases^phosphorylation', 222),
#  ('affects^reaction|decreases^activity', 216),
#  ('affects^cotreatment|decreases^reaction|increases^expression|increases^secretion',
#   214),
#  ('decreases^abundance|decreases^reaction', 213),
#  ('decreases^activity|decreases^reaction|increases^expression', 208),
#  ('decreases^activity|decreases^expression|decreases^reaction', 207),
#  ('decreases^reaction|increases^acetylation', 207),
#  ('increases^activity|increases^expression|increases^reaction', 206),
#  ('affects^reaction|affects^response to substance', 201),
#  ('increases^abundance|increases^expression|increases^reaction', 201),
#  ('affects^methylation|increases^abundance', 199),
#  ('increases^export', 193),
#  ('increases^stability', 192),
#  ('affects^cotreatment|increases^metabolic processing', 189),
#  ('affects^cotreatment|increases^expression|increases^secretion', 187),
#  ('increases^metabolic processing|increases^reaction', 186),
#  ('affects^cotreatment|increases^activity|increases^cleavage', 181),
#  ('affects^phosphorylation|affects^reaction', 181),
#  ('affects^localization|decreases^reaction|increases^phosphorylation', 179),
#  ('increases^chemical synthesis|increases^reaction', 179),
#  ('decreases^activity|decreases^reaction|increases^reaction', 177),
#  ('affects^binding|decreases^reaction|increases^abundance|increases^activity',
#   177),
#  ('affects^binding|decreases^activity|decreases^response to substance', 176),
#  ('decreases^expression|decreases^reaction|increases^abundance', 173),
#  ('decreases^reaction|increases^activity|increases^localization', 172),
#  ('decreases^activity|decreases^metabolic processing', 171),
#  ('affects^cotreatment|decreases^reaction|increases^phosphorylation|increases^reaction',
#   170),
#  ('affects^binding|affects^cotreatment', 170),
#  ('decreases^activity|increases^response to substance', 168),
#  ('decreases^reaction|increases^degradation|increases^phosphorylation', 167),
#  ('increases^activity|increases^cleavage|increases^reaction', 167),
#  ('increases^chemical synthesis|increases^expression', 167),
#  ('affects^activity|affects^binding', 167),
#  ('affects^binding|decreases^reaction|increases^activity|increases^reaction',
#   167),
#  ('increases^reaction|increases^response to substance', 166),
#  ('decreases^degradation', 164),
#  ('affects^localization|decreases^reaction|increases^expression', 162),
#  ('affects^localization|increases^activity', 160),
#  ('affects^activity|affects^cotreatment', 160),
#  ('decreases^abundance|decreases^activity', 159),
#  ('affects^cotreatment|affects^reaction|increases^secretion', 159),
#  ('affects^binding|decreases^reaction|increases^phosphorylation', 155),
#  ('decreases^expression|decreases^secretion', 154),
#  ('affects^localization|decreases^reaction|increases^activity', 154),
#  ('increases^oxidation|increases^reaction', 149),
#  ('decreases^expression|decreases^phosphorylation', 149),
#  ('decreases^activity|increases^abundance', 147),
#  ('affects^expression|increases^abundance', 147),
#  ('affects^cotreatment|affects^metabolic processing', 145),
#  ('decreases^response to substance|increases^reaction', 145),
#  ('affects^binding|decreases^reaction|increases^activity|increases^expression',
#   144),
#  ('affects^cotreatment|affects^reaction|decreases^expression', 144),
#  ('affects^binding|decreases^reaction|increases^acetylation|increases^activity|increases^expression',
#   144),
#  ('affects^metabolic processing|decreases^reaction', 141),
#  ('increases^abundance|increases^metabolic processing', 141),
#  ('affects^reaction|increases^uptake', 141),
#  ('affects^cotreatment|decreases^phosphorylation|decreases^reaction', 140),
#  ('increases^sulfation', 138),
#  ('decreases^activity|increases^expression', 137),
#  ('affects^cotreatment|affects^response to substance|decreases^expression',
#   136),
#  ('affects^cotreatment|increases^abundance|increases^reaction', 136),
#  ('affects^cotreatment|decreases^secretion', 135),
#  ('affects^reaction|increases^activity|increases^phosphorylation', 135),
#  ('decreases^activity|decreases^reaction|increases^abundance', 135),
#  ('affects^cotreatment|increases^chemical synthesis', 135),
#  ('affects^cotreatment|increases^cleavage|increases^reaction', 132),
#  ('affects^cotreatment|increases^chemical synthesis|increases^reaction', 131),
#  ('affects^cotreatment|increases^reduction', 130),
#  ('affects^cotreatment|decreases^reaction|increases^chemical synthesis', 130),
#  ('decreases^reaction|increases^reaction|increases^transport', 126),
#  ('affects^chemical synthesis', 125),
#  ('affects^reaction|increases^transport', 124),
#  ('affects^cotreatment|decreases^reaction|increases^reduction', 124),
#  ('decreases^localization', 124),
#  ('decreases^abundance|decreases^expression', 124),
#  ('decreases^expression|increases^expression', 124),
#  ('decreases^abundance|increases^expression', 123),
#  ('decreases^expression|decreases^response to substance', 122),
#  ('affects^export', 121),
#  ('affects^localization|increases^phosphorylation', 121),
#  ('affects^binding|decreases^reaction|increases^secretion', 121),
#  ('decreases^reaction|increases^reaction|increases^uptake', 120),
#  ('increases^import', 120),
#  ('increases^activity|increases^localization', 119),
#  ('affects^binding|decreases^expression|decreases^reaction', 117),
#  ('affects^activity|decreases^reaction', 117),
#  ('affects^abundance|affects^reaction', 115),
#  ('increases^activity|increases^response to substance', 115),
#  ('decreases^activity|decreases^phosphorylation|decreases^reaction', 114),
#  ('affects^cotreatment|decreases^reaction|increases^degradation', 114),
#  ('affects^cotreatment|affects^reaction|decreases^expression|decreases^reaction',
#   114),
#  ('affects^cotreatment|decreases^reaction|increases^oxidation', 113),
#  ('affects^expression|affects^reaction|increases^response to substance', 112),
#  ('affects^binding|decreases^uptake', 111),
#  ('decreases^reaction|increases^abundance|increases^phosphorylation', 110),
#  ('increases^degradation|increases^reaction', 110),
#  ('decreases^reaction|increases^sulfation', 110),
#  ('decreases^reaction|increases^expression|increases^response to substance',
#   108),
#  ('affects^binding|increases^activity|increases^expression|increases^reaction',
#   107),
#  ('decreases^acetylation', 107),
#  ('affects^cotreatment|increases^expression|increases^phosphorylation', 107),
#  ('affects^cotreatment|increases^activity|increases^phosphorylation', 107),
#  ('affects^binding|decreases^expression|increases^reaction', 107),
#  ('affects^localization|decreases^expression', 106),
#  ('increases^cleavage|increases^response to substance', 105),
#  ('affects^binding|affects^folding|decreases^reaction', 105),
#  ('affects^cotreatment|decreases^reaction|decreases^secretion', 104),
#  ('affects^reaction|decreases^response to substance', 104),
#  ('affects^binding|affects^folding|increases^reaction', 104),
#  ('decreases^cleavage', 103),
#  ('decreases^reaction|increases^activity|increases^phosphorylation|increases^reaction',
#   102),
#  ('affects^binding|affects^cotreatment|increases^expression', 100),
#  ('affects^abundance|affects^cotreatment|affects^response to substance', 98),
#  ('affects^cotreatment|increases^oxidation', 98),
#  ('affects^cotreatment|affects^phosphorylation', 98),
#  ('affects^cotreatment|decreases^expression|increases^abundance', 98),
#  ('increases^activity|increases^metabolic processing', 97),
#  ('affects^cotreatment|decreases^reaction|increases^activity|increases^expression',
#   97),
#  ('decreases^response to substance|increases^activity', 95),
#  ('decreases^metabolic processing', 95),
#  ('affects^cotreatment|affects^reaction|increases^activity', 95),
#  ('affects^binding|decreases^activity|decreases^reaction|increases^expression',
#   94),
#  ('increases^glutathionylation', 94),
#  ('decreases^uptake', 93),
#  ('affects^uptake', 93),
#  ('affects^reaction|increases^activity|increases^expression', 93),
#  ('increases^expression|increases^stability', 92),
#  ('decreases^expression|increases^activity', 92),
#  ('decreases^reaction|increases^methylation', 92),
#  ('increases^expression|increases^reaction|increases^secretion', 92),
#  ('affects^reaction|decreases^reaction|increases^secretion', 92),
#  ('affects^binding|increases^secretion', 91),
#  ('increases^abundance|increases^response to substance', 90),
#  ('affects^activity|affects^reaction', 90),
#  ('affects^folding', 89),
#  ('affects^cotreatment|decreases^expression|increases^methylation', 89),
#  ('affects^binding|affects^folding', 88),
#  ('affects^binding|decreases^activity|increases^reaction', 88),
#  ('affects^acetylation|affects^methylation', 88),
#  ('decreases^reaction|increases^activity|increases^chemical synthesis', 87),
#  ('decreases^reaction|increases^activity|increases^secretion', 87),
#  ('affects^activity|affects^binding|decreases^reaction', 87),
#  ('decreases^reaction|increases^glucuronidation', 86),
#  ('increases^abundance|increases^activity|increases^reaction', 86),
#  ('affects^cotreatment|decreases^reaction|increases^response to substance',
#   85),
#  ('affects^binding|affects^cotreatment|increases^activity', 85),
#  ('affects^cotreatment|decreases^reaction|increases^reaction|increases^secretion',
#   85),
#  ('affects^binding|increases^phosphorylation', 85),
#  ('affects^reaction|decreases^phosphorylation', 85),
#  ('decreases^activity|decreases^chemical synthesis', 84),
#  ('affects^cotreatment|affects^reaction|increases^phosphorylation', 84),
#  ('affects^splicing|decreases^expression', 84),
#  ('decreases^reaction|increases^abundance|increases^metabolic processing', 83),
#  ('affects^cotreatment|decreases^reaction|increases^activity|increases^phosphorylation',
#   83),
#  ('decreases^activity|increases^phosphorylation', 83),
#  ('affects^cotreatment|increases^activity|increases^expression', 83),
#  ('affects^cotreatment|increases^degradation', 83),
#  ('increases^activity|increases^expression|increases^phosphorylation', 83),
#  ('increases^cleavage|increases^expression', 83),
#  ('affects^cotreatment|affects^expression|decreases^reaction', 83),
#  ('increases^expression|increases^reaction|increases^response to substance',
#   83),
#  ('increases^splicing', 82),
#  ('affects^reaction|decreases^reaction|increases^phosphorylation', 81),
#  ('affects^transport|increases^reaction', 81),
#  ('increases^activity|increases^uptake', 81),
#  ('affects^cotreatment|decreases^reaction|increases^activity|increases^reaction',
#   80),
#  ('decreases^expression|increases^phosphorylation', 80),
#  ('affects^cotreatment|decreases^reaction|increases^activity|increases^cleavage',
#   80),
#  ('affects^binding|increases^activity|increases^phosphorylation', 80),
#  ('increases^chemical synthesis|increases^oxidation', 80),
#  ('affects^binding|affects^localization', 80),
#  ('increases^expression|increases^localization', 80),
#  ('decreases^expression|increases^degradation', 79),
#  ('increases^activity|increases^chemical synthesis', 79),
#  ('affects^reaction|increases^response to substance', 79),
#  ('affects^reaction|decreases^reaction|increases^activity', 79),
#  ('increases^export|increases^reaction', 78),
#  ('affects^cotreatment|decreases^abundance', 77),
#  ('decreases^expression|decreases^reaction|increases^degradation', 77),
#  ('increases^acetylation|increases^expression', 77),
#  ('affects^reaction|increases^phosphorylation|increases^reaction', 76),
#  ('decreases^methylation|decreases^reaction', 75),
#  ('affects^binding|decreases^reaction|increases^transport', 75),
#  ('affects^cotreatment|decreases^reaction|decreases^response to substance',
#   74),
#  ('decreases^expression|decreases^reaction|decreases^secretion', 73),
#  ('decreases^abundance|increases^reaction', 73),
#  ('decreases^reaction|decreases^uptake', 73),
#  ('decreases^abundance|decreases^reaction|increases^expression', 73),
#  ('increases^abundance|increases^phosphorylation', 73),
#  ('affects^cotreatment|affects^expression|affects^reaction|increases^response to substance',
#   72),
#  ('affects^reaction|increases^abundance|increases^expression', 72),
#  ('affects^binding|affects^reaction|increases^activity', 71),
#  ('decreases^activity|decreases^reaction|increases^chemical synthesis', 71),
#  ('affects^reaction|decreases^reaction|increases^transport', 70),
#  ('affects^binding|increases^transport', 70),
#  ('affects^cotreatment|decreases^activity|decreases^response to substance',
#   69),
#  ('decreases^expression|decreases^phosphorylation|decreases^reaction', 69),
#  ('affects^abundance|decreases^reaction|increases^expression', 69),
#  ('affects^binding|affects^cotreatment|increases^expression|increases^reaction',
#   69),
#  ('affects^binding|increases^phosphorylation|increases^reaction', 68),
#  ('decreases^acetylation|decreases^reaction', 67),
#  ('affects^export|decreases^reaction', 67),
#  ('decreases^activity|decreases^uptake', 67),
#  ('decreases^reaction|increases^cleavage|increases^expression', 66),
#  ('affects^reaction|increases^metabolic processing', 66),
#  ('affects^cotreatment|decreases^reaction|increases^metabolic processing', 66),
#  ('decreases^reaction|increases^chemical synthesis|increases^metabolic processing',
#   64),
#  ('decreases^activity|increases^activity', 64),
#  ('affects^cotreatment|decreases^activity|decreases^reaction|increases^expression',
#   64),
#  ('affects^binding|increases^abundance', 64),
#  ('affects^response to substance|increases^abundance', 64),
#  ('increases^ubiquitination', 63),
#  ('affects^cotreatment|affects^reaction|decreases^reaction|increases^expression',
#   63),
#  ('decreases^reaction|increases^chemical synthesis|increases^reaction', 63),
#  ('decreases^transport', 63),
#  ('affects^abundance|affects^response to substance', 63),
#  ('affects^reaction|decreases^reaction|increases^abundance', 62),
#  ('affects^cotreatment|decreases^abundance|decreases^reaction', 62),
#  ('affects^binding|decreases^reaction|increases^activity|increases^secretion',
#   62),
#  ('affects^localization|decreases^expression|decreases^reaction', 62),
#  ('affects^cotreatment|decreases^reaction|increases^uptake', 62),
#  ('affects^cotreatment|decreases^reaction|increases^transport', 61),
#  ('increases^chemical synthesis|increases^hydroxylation', 60),
#  ('affects^response to substance|decreases^reaction', 60),
#  ('affects^abundance|decreases^reaction', 60),
#  ('affects^cotreatment|affects^reaction|increases^cleavage|increases^secretion',
#   60),
#  ('affects^cotreatment|increases^localization', 60),
#  ('affects^binding|affects^reaction|decreases^reaction', 59),
#  ('decreases^reaction|increases^ubiquitination', 59),
#  ('decreases^reaction|decreases^response to substance|increases^reaction', 59),
#  ('decreases^activity|decreases^reaction|increases^activity|increases^phosphorylation',
#   59),
#  ('decreases^reaction|increases^abundance|increases^activity|increases^phosphorylation',
#   58),
#  ('increases^chemical synthesis|increases^reduction', 58),
#  ('affects^cotreatment|affects^reduction', 58),
#  ('decreases^phosphorylation|increases^expression', 58),
#  ('affects^cotreatment|decreases^reaction|increases^abundance|increases^reaction',
#   57),
#  ('affects^binding|decreases^activity|decreases^reaction|increases^abundance',
#   57),
#  ('affects^binding|decreases^reaction|increases^abundance', 57),
#  ('affects^cotreatment|affects^response to substance|decreases^reaction|increases^expression',
#   56),
#  ('affects^binding|decreases^response to substance', 56),
#  ('decreases^reaction|increases^stability', 56),
#  ('decreases^chemical synthesis|decreases^expression', 56),
#  ('affects^cotreatment|affects^reaction|increases^cleavage', 56),
#  ('affects^localization|affects^reaction|decreases^reaction', 55),
#  ('affects^metabolic processing|increases^reaction', 55),
#  ('affects^reaction|decreases^secretion', 55),
#  ('affects^cotreatment|affects^response to substance|increases^expression|increases^reaction',
#   54),
#  ('decreases^cleavage|decreases^reaction', 54),
#  ('decreases^activity|decreases^transport', 54),
#  ('affects^reaction|decreases^abundance', 53),
#  ('affects^cotreatment|increases^expression|increases^metabolic processing',
#   53),
#  ('affects^binding|increases^uptake', 53),
#  ('affects^binding|decreases^reaction|increases^degradation', 52),
#  ('affects^cotreatment|increases^uptake', 52),
#  ('affects^phosphorylation|decreases^reaction', 52),
#  ('decreases^activity|decreases^phosphorylation|increases^reaction', 52),
#  ('affects^binding|decreases^response to substance|increases^activity', 52),
#  ('affects^activity|affects^cotreatment|increases^reduction', 52),
#  ('affects^splicing|increases^expression', 52),
#  ('affects^binding|increases^degradation', 51),
#  ('increases^degradation|increases^phosphorylation', 51),
#  ('affects^cotreatment|decreases^phosphorylation|increases^reaction', 51),
#  ('affects^binding|decreases^abundance|decreases^activity', 51),
#  ('increases^expression|increases^uptake', 51),
#  ('affects^binding|decreases^activity|decreases^reaction|increases^phosphorylation',
#   51),
#  ('affects^localization|decreases^activity', 50),
#  ('decreases^degradation|decreases^reaction', 50),
#  ('decreases^stability', 50),
#  ('affects^cotreatment|decreases^activity|decreases^expression|decreases^reaction',
#   50),
#  ('increases^expression|increases^phosphorylation|increases^reaction', 50),
#  ('increases^phosphorylation|increases^response to substance', 50),
#  ('decreases^reaction|increases^cleavage|increases^response to substance', 49),
#  ('affects^cotreatment|increases^transport', 49),
#  ('affects^binding|decreases^abundance|increases^activity', 49),
#  ('affects^response to substance|decreases^reaction|increases^expression', 48),
#  ('affects^cotreatment|increases^mutagenesis', 48),
#  ('increases^activity|increases^secretion', 48),
#  ('affects^binding|decreases^reaction|increases^expression|increases^reaction',
#   48),
#  ('affects^binding|affects^cotreatment|decreases^reaction|increases^activity',
#   47),
#  ('affects^cotreatment|decreases^expression|increases^response to substance',
#   47),
#  ('affects^reaction|decreases^reaction|increases^cleavage', 47),
#  ('affects^cotreatment|increases^abundance|increases^expression|increases^phosphorylation|increases^stability',
#   47),
#  ('decreases^localization|decreases^reaction', 46),
#  ('decreases^chemical synthesis', 46),
#  ('decreases^expression|increases^abundance|increases^reaction', 46),
#  ('affects^reaction|increases^activity|increases^cleavage', 46),
#  ('decreases^activity|decreases^import', 46),
#  ('affects^reaction|decreases^phosphorylation|decreases^reaction', 46),
#  ('affects^cleavage', 45),
#  ('affects^cotreatment|decreases^reaction|increases^mutagenesis', 45),
#  ('increases^import|increases^reaction', 45),
#  ('affects^binding|affects^metabolic processing', 45),
#  ('increases^abundance|increases^activity|increases^expression', 44),
#  ('decreases^phosphorylation|increases^activity', 44),
#  ('affects^cotreatment|affects^localization|increases^reaction', 44),
#  ('affects^localization|decreases^reaction|increases^reaction', 44),
#  ('affects^reaction|increases^chemical synthesis', 44),
#  ('affects^cotreatment|affects^localization|decreases^reaction|increases^activity',
#   44),
#  ('affects^oxidation', 44),
#  ('decreases^secretion|increases^reaction', 44),
#  ('increases^hydrolysis|increases^reaction', 44),
#  ('affects^binding|decreases^reaction|decreases^response to substance|increases^activity',
#   43),
#  ('affects^cotreatment|affects^localization|increases^expression', 43),
#  ('affects^expression|affects^reaction|affects^response to substance', 43),
#  ('affects^cotreatment|decreases^reaction|increases^chemical synthesis|increases^reaction',
#   42),
#  ('decreases^reaction|increases^activity|increases^localization|increases^phosphorylation',
#   42),
#  ('increases^activity|increases^transport', 42),
#  ('affects^expression|increases^response to substance', 42),
#  ('affects^response to substance|decreases^activity', 41),
#  ('affects^activity|affects^expression', 41),
#  ('affects^reaction|affects^secretion', 41),
#  ('increases^chemical synthesis|increases^metabolic processing|increases^reaction',
#   41),
#  ('decreases^phosphorylation|decreases^reaction|increases^activity', 40),
#  ('affects^cotreatment|increases^chemical synthesis|increases^metabolic processing',
#   40),
#  ('decreases^methylation|increases^expression', 40),
#  ('affects^binding|increases^activity|increases^secretion', 40),
#  ('affects^cotreatment|affects^expression|affects^reaction|affects^response to substance',
#   40),
#  ('affects^cotreatment|increases^expression|increases^reaction|increases^secretion',
#   40),
#  ('affects^binding|affects^cotreatment|decreases^reaction|increases^expression',
#   40),
#  ('decreases^reaction|increases^splicing', 39),
#  ('decreases^abundance|decreases^activity|decreases^reaction', 39),
#  ('affects^cotreatment|affects^reaction|increases^metabolic processing', 39),
#  ('increases^abundance|increases^secretion', 39),
#  ('affects^binding|increases^cleavage', 39),
#  ('decreases^degradation|increases^expression', 38),
#  ('affects^cotreatment|affects^reaction|increases^expression|increases^reaction',
#   38),
#  ('decreases^phosphorylation|increases^response to substance', 38),
#  ('increases^localization|increases^reaction', 38),
#  ('affects^binding|affects^reaction|increases^expression', 38),
#  ('decreases^reaction|decreases^response to substance|increases^expression',
#   38),
#  ('affects^binding|affects^transport', 38),
#  ('affects^binding|affects^localization|increases^reaction', 38),
#  ('decreases^acetylation|decreases^expression', 38),
#  ('decreases^expression|increases^reaction|increases^response to substance',
#   38),
#  ('affects^binding|increases^acetylation|increases^activity|increases^expression',
#   38),
#  ('affects^reaction|affects^transport', 37),
#  ('affects^binding|decreases^reaction|increases^activity|increases^phosphorylation',
#   37),
#  ('decreases^reaction|increases^mutagenesis', 37),
#  ('affects^binding|increases^response to substance', 37),
#  ('decreases^reaction|increases^activity|increases^expression|increases^phosphorylation',
#   37),
#  ('decreases^reaction|increases^abundance|increases^activity|increases^expression',
#   36),
#  ('affects^cotreatment|decreases^secretion|increases^reaction', 36),
#  ('affects^binding|decreases^reaction|increases^activity|increases^phosphorylation|increases^reaction',
#   36),
#  ('affects^localization|increases^expression|increases^reaction', 36),
#  ('affects^binding|increases^activity|increases^transport', 36),
#  ('affects^cotreatment|increases^reaction|increases^response to substance',
#   36),
#  ('affects^binding|affects^localization|decreases^reaction', 36),
#  ('affects^binding|affects^folding|affects^reaction', 36),
#  ('decreases^methylation|increases^abundance', 36),
#  ('affects^binding|decreases^reaction|decreases^response to substance|increases^acetylation|increases^activity|increases^expression',
#   36),
#  ('affects^reaction|increases^expression|increases^response to substance', 36),
#  ('affects^abundance|affects^cotreatment', 35),
#  ('decreases^reaction|increases^chemical synthesis|increases^hydroxylation',
#   35),
#  ('affects^cotreatment|affects^localization|affects^reaction', 35),
#  ('affects^reaction|increases^degradation', 35),
#  ('decreases^expression|decreases^reaction|increases^phosphorylation', 35),
#  ('affects^activity|affects^cotreatment|decreases^reaction', 35),
#  ('decreases^reaction|decreases^stability', 35),
#  ('affects^cotreatment|increases^expression|increases^response to substance',
#   35),
#  ('affects^cotreatment|increases^activity|increases^phosphorylation|increases^reaction',
#   35),
#  ('decreases^reaction|increases^activity|increases^transport', 34),
#  ('decreases^reaction|increases^abundance|increases^secretion', 34),
#  ('affects^cotreatment|decreases^expression|increases^expression', 34),
#  ('decreases^activity|decreases^reaction|increases^secretion', 34),
#  ('increases^abundance|increases^methylation', 34),
#  ('affects^reaction|increases^reaction|increases^secretion', 34),
#  ('decreases^reaction|increases^acetylation|increases^reaction', 34),
#  ('affects^reaction|increases^activity|increases^reaction', 34),
#  ('increases^nitrosation', 34),
#  ('affects^metabolic processing|affects^reaction', 34),
#  ('affects^cotreatment|increases^degradation|increases^reaction', 34),
#  ('affects^cotreatment|affects^reaction|decreases^activity', 34),
#  ('affects^cotreatment|decreases^reaction|increases^abundance|increases^activity',
#   33),
#  ('increases^response to substance|increases^secretion', 33),
#  ('affects^binding|increases^abundance|increases^reaction', 33),
#  ('affects^cotreatment|decreases^reaction|increases^localization', 33),
#  ('decreases^activity|decreases^export', 33),
#  ('affects^cotreatment|affects^reaction|decreases^reaction|increases^secretion',
#   33),
#  ('affects^reaction|affects^response to substance|increases^expression', 33),
#  ('affects^binding|decreases^reaction|increases^phosphorylation|increases^reaction',
#   32),
#  ('affects^binding|increases^activity|increases^response to substance', 32),
#  ('affects^metabolic processing|increases^activity', 32),
#  ('decreases^reaction|increases^chemical synthesis|increases^oxidation', 32),
#  ('affects^metabolic processing|affects^response to substance', 32),
#  ('affects^cotreatment|increases^abundance|increases^secretion', 32),
#  ('increases^abundance|increases^activity|increases^phosphorylation', 32),
#  ('affects^cotreatment|affects^phosphorylation|affects^reaction', 32),
#  ('affects^cotreatment|affects^response to substance|decreases^expression|decreases^reaction',
#   32),
#  ('affects^activity|affects^localization|decreases^reaction', 32),
#  ('increases^abundance|increases^oxidation', 31),
#  ('affects^cotreatment|decreases^reaction|increases^reaction|increases^transport',
#   31),
#  ('decreases^reaction|increases^expression|increases^stability', 31),
#  ('affects^binding|decreases^reaction|increases^chemical synthesis', 31),
#  ('affects^localization|decreases^phosphorylation', 31),
#  ('affects^localization|increases^activity|increases^expression', 31),
#  ('affects^reaction|increases^abundance|increases^activity', 31),
#  ('affects^binding|affects^expression', 31),
#  ('affects^cotreatment|affects^expression|increases^chemical synthesis', 30),
#  ('increases^expression|increases^metabolic processing', 30),
#  ('increases^glucuronidation|increases^reaction', 30),
#  ('affects^activity|decreases^reaction|increases^activity|increases^reaction',
#   30),
#  ('affects^binding|decreases^activity|decreases^expression|decreases^reaction',
#   30),
#  ('affects^binding|affects^cotreatment|increases^activity|increases^reaction',
#   30),
#  ('affects^cotreatment|decreases^reaction|increases^chemical synthesis|increases^oxidation',
#   30),
#  ('affects^binding|affects^cotreatment|decreases^reaction|increases^chemical synthesis|increases^oxidation',
#   30),
#  ('affects^activity|affects^binding|decreases^reaction|increases^reaction',
#   30),
#  ('affects^binding|decreases^activity|decreases^reaction|increases^activity',
#   30),
#  ('affects^cotreatment|increases^activity|increases^expression|increases^reaction',
#   30),
#  ('decreases^activity|decreases^degradation', 30),
#  ('affects^binding|affects^cotreatment|decreases^activity', 29),
#  ('affects^expression|affects^reaction|increases^abundance', 29),
#  ('increases^activity|increases^import', 29),
#  ('increases^acetylation|increases^reaction', 29),
#  ('affects^binding|decreases^abundance', 29),
#  ('affects^binding|affects^response to substance|decreases^activity', 29),
#  ('affects^cotreatment|affects^expression|increases^abundance', 29),
#  ('decreases^reaction|increases^localization|increases^phosphorylation', 28),
#  ('increases^metabolic processing|increases^response to substance', 28),
#  ('decreases^export|decreases^reaction', 28),
#  ('decreases^reaction|increases^chemical synthesis|increases^reduction', 28),
#  ('decreases^methylation|increases^reaction', 28),
#  ('affects^reaction|decreases^reaction|increases^activity|increases^phosphorylation',
#   27),
#  ('decreases^reaction|increases^activity|increases^chemical synthesis|increases^expression',
#   27),
#  ('affects^binding|increases^metabolic processing', 27),
#  ('affects^cotreatment|affects^expression|decreases^reaction|increases^reaction',
#   27),
#  ('decreases^reaction|increases^activity|increases^metabolic processing', 27),
#  ('decreases^reaction|increases^expression|increases^localization', 27),
#  ('affects^binding|increases^chemical synthesis', 27),
#  ('affects^reaction|increases^oxidation', 27),
#  ('affects^glucuronidation', 27),
#  ('affects^localization|decreases^activity|decreases^reaction', 27),
#  ('decreases^reaction|increases^glutathionylation', 27),
#  ('decreases^abundance|increases^activity', 27),
#  ('increases^chemical synthesis|increases^expression|increases^reaction', 27),
#  ('affects^cotreatment|increases^activity|increases^transport', 27),
#  ('affects^cotreatment|affects^localization|decreases^reaction|increases^expression',
#   26),
#  ('decreases^activity|decreases^reaction|increases^activity', 26),
#  ('decreases^activity|decreases^reaction|decreases^response to substance', 26),
#  ('increases^hydroxylation|increases^reaction', 26),
#  ('affects^cotreatment|affects^transport', 26),
#  ('increases^chemical synthesis|increases^oxidation|increases^reaction', 26),
#  ('affects^response to substance|increases^activity', 26),
#  ('affects^cotreatment|affects^secretion', 26),
#  ('affects^hydroxylation', 26),
#  ('affects^binding|decreases^reaction|increases^activity|increases^import',
#   26),
#  ('affects^binding|affects^cotreatment|decreases^expression', 26),
#  ('affects^abundance|affects^metabolic processing', 25),
#  ('affects^cotreatment|decreases^reaction|increases^expression|increases^phosphorylation',
#   25),
#  ('increases^activity|increases^expression|increases^localization', 25),
#  ('affects^cotreatment|decreases^activity|increases^reaction', 25),
#  ('affects^reaction|decreases^reaction|increases^oxidation', 25),
#  ('affects^cotreatment|increases^chemical synthesis|increases^oxidation', 25),
#  ('decreases^expression|decreases^uptake', 25),
#  ('affects^binding|decreases^activity|increases^expression', 25),
#  ('affects^binding|decreases^expression|decreases^reaction|increases^activity',
#   25),
#  ('decreases^activity|increases^uptake', 25),
#  ('decreases^reaction|increases^cleavage|increases^secretion', 25),
#  ('affects^cotreatment|increases^expression|increases^localization', 25),
#  ('decreases^reaction|increases^activity|increases^oxidation', 24),
#  ('increases^activity|increases^localization|increases^reaction', 24),
#  ('affects^binding|increases^activity|increases^reaction|increases^transport',
#   24),
#  ('affects^cotreatment|increases^hydroxylation', 24),
#  ('decreases^activity|decreases^secretion', 24),
#  ('affects^binding|affects^response to substance', 24),
#  ('affects^binding|decreases^activity|decreases^reaction|increases^secretion',
#   24),
#  ('affects^cleavage|affects^reaction|affects^response to substance', 24),
#  ('affects^cotreatment|increases^cleavage|increases^secretion', 24),
#  ('affects^cotreatment|decreases^expression|decreases^phosphorylation', 24),
#  ('affects^binding|decreases^activity|decreases^reaction|increases^activity|increases^phosphorylation',
#   24),
#  ('affects^binding|increases^abundance|increases^expression|increases^reaction',
#   24),
#  ('increases^abundance|increases^activity|increases^phosphorylation|increases^reaction',
#   24),
#  ('affects^reaction|increases^expression|increases^secretion', 24),
#  ('affects^hydrolysis', 24),
#  ('affects^cotreatment|affects^reaction|increases^abundance', 24),
#  ('affects^uptake|decreases^reaction', 24),
#  ('affects^reaction|increases^activity|increases^expression|increases^reaction',
#   24),
#  ('affects^binding|affects^reaction|increases^transport', 24),
#  ('affects^binding|decreases^response to substance|increases^acetylation|increases^activity|increases^expression',
#   24),
#  ('increases^abundance|increases^activity|increases^cleavage|increases^localization',
#   24),
#  ('decreases^reaction|increases^oxidation|increases^reduction', 24),
#  ('affects^cotreatment|affects^expression|affects^methylation', 24),
#  ('affects^activity|affects^localization', 23),
#  ('affects^response to substance|increases^secretion', 23),
#  ('affects^cotreatment|increases^acetylation', 23),
#  ('increases^activity|increases^oxidation', 23),
#  ('affects^reduction', 23),
#  ('decreases^reaction|increases^activity|increases^response to substance', 23),
#  ('decreases^export', 23),
#  ('affects^binding|increases^degradation|increases^reaction', 23),
#  ('affects^expression|affects^localization', 23),
#  ('affects^metabolic processing|decreases^activity', 23),
#  ('affects^abundance|decreases^expression', 23),
#  ('affects^cotreatment|increases^metabolic processing|increases^reaction', 23),
#  ('affects^cotreatment|decreases^reaction|increases^activity|increases^transport',
#   23),
#  ('decreases^activity|decreases^cleavage', 22),
#  ('increases^abundance|increases^cleavage', 22),
#  ('increases^degradation|increases^ubiquitination', 22),
#  ('increases^sumoylation', 22),
#  ('affects^degradation', 22),
#  ('affects^response to substance|decreases^reaction|increases^phosphorylation',
#   22),
#  ('increases^mutagenesis|increases^reaction', 22),
#  ('increases^methylation|increases^reaction', 22),
#  ('decreases^response to substance|increases^phosphorylation', 22),
#  ('affects^binding|decreases^reaction|increases^activity|increases^expression|increases^reaction',
#   22),
#  ('decreases^abundance|decreases^reaction|increases^activity', 22),
#  ('affects^cotreatment|affects^reaction|increases^activity|increases^phosphorylation',
#   22),
#  ('affects^reaction|increases^secretion|increases^uptake', 22),
#  ('affects^cotreatment|decreases^reaction|increases^abundance|increases^expression',
#   22),
#  ('affects^secretion|increases^reaction', 21),
#  ('increases^expression|increases^transport', 21),
#  ('decreases^reaction|decreases^secretion|increases^reaction', 21),
#  ('decreases^activity|increases^metabolic processing', 21),
#  ('decreases^abundance|increases^oxidation', 21),
#  ('decreases^activity|decreases^localization', 21),
#  ('affects^expression|affects^phosphorylation', 21),
#  ('decreases^expression|increases^secretion', 21),
#  ('affects^binding|decreases^reaction|increases^activity|increases^transport',
#   21),
#  ('affects^binding|decreases^reaction|decreases^transport|increases^activity',
#   21),
#  ('affects^cotreatment|increases^abundance|increases^phosphorylation', 21),
#  ('affects^cotreatment|decreases^expression|increases^activity', 21),
#  ('affects^binding|affects^reaction|increases^secretion', 21),
#  ('affects^cotreatment|decreases^reaction|increases^chemical synthesis|increases^expression',
#   21),
#  ('affects^localization|increases^activity|increases^reaction', 20),
#  ('affects^binding|increases^reaction|increases^transport', 20),
#  ('decreases^activity|increases^phosphorylation|increases^reaction', 20),
#  ('affects^reaction|decreases^cleavage', 20),
#  ('decreases^uptake|increases^reaction', 20),
#  ('decreases^ubiquitination', 20),
#  ('decreases^reaction|increases^activity|increases^cleavage|increases^reaction',
#   20),
#  ('affects^binding|decreases^activity|decreases^expression', 20),
#  ('decreases^activity|decreases^chemical synthesis|decreases^reaction', 20),
#  ('decreases^reaction|increases^oxidation|increases^reaction', 20),
#  ('decreases^phosphorylation|decreases^reaction|decreases^response to substance',
#   20),
#  ('affects^binding|decreases^reaction|increases^reaction|increases^transport',
#   20),
#  ('affects^activity|affects^binding|increases^reaction', 20),
#  ('decreases^phosphorylation|decreases^reaction|increases^expression', 20),
#  ('affects^cotreatment|increases^chemical synthesis|increases^oxidation|increases^reaction',
#   20),
#  ('affects^secretion|decreases^reaction', 20),
#  ('decreases^reaction|decreases^response to substance|increases^activity', 20),
#  ('increases^reaction|increases^reduction', 20),
#  ('decreases^prenylation', 20),
#  ('affects^binding|affects^cotreatment|increases^activity|increases^expression',
#   20),
#  ('affects^response to substance|increases^phosphorylation', 20),
#  ('increases^activity|increases^chemical synthesis|increases^expression', 20),
#  ('affects^reaction|increases^localization', 20),
#  ('increases^export|increases^expression', 20),
#  ('affects^reaction|decreases^expression|increases^abundance', 20),
#  ('affects^cotreatment|decreases^reaction|increases^activity|increases^expression|increases^reaction',
#   20),
#  ('affects^import|decreases^reaction', 20),
#  ('decreases^expression|increases^chemical synthesis', 20),
#  ('affects^binding|increases^activity|increases^chemical synthesis', 20),
#  ('affects^cotreatment|affects^reaction|decreases^phosphorylation|decreases^reaction',
#   20),
#  ('decreases^hydroxylation', 19),
#  ('affects^binding|decreases^reaction|increases^metabolic processing', 19),
#  ('affects^binding|increases^activity|increases^phosphorylation|increases^reaction',
#   19),
#  ('affects^activity|affects^phosphorylation', 19),
#  ('decreases^reaction|increases^activity|increases^expression|increases^reaction',
#   19),
#  ('affects^cotreatment|increases^ubiquitination', 19),
#  ('decreases^expression|increases^methylation', 19),
#  ('decreases^reaction|increases^export|increases^reaction', 19),
#  ('increases^reaction|increases^ubiquitination', 19),
#  ('increases^cleavage|increases^expression|increases^reaction', 19),
#  ('decreases^expression|decreases^reaction|increases^expression', 19),
#  ('decreases^chemical synthesis|decreases^reaction', 19),
#  ('affects^cotreatment|decreases^expression|decreases^secretion', 19),
#  ('affects^cotreatment|increases^cleavage|increases^expression', 19),
#  ('affects^cotreatment|increases^abundance|increases^oxidation', 19),
#  ('increases^abundance|increases^expression|increases^phosphorylation|increases^reaction',
#   19),
#  ('decreases^oxidation', 19),
#  ('affects^ubiquitination|decreases^reaction|increases^expression', 19),
#  ('affects^metabolic processing|increases^abundance', 18),
#  ('affects^binding|decreases^activity|increases^activity', 18),
#  ('affects^cotreatment|affects^oxidation', 18),
#  ('affects^binding|affects^reaction|increases^reaction|increases^transport',
#   18),
#  ('affects^reaction|decreases^activity|decreases^response to substance', 18),
# ...
#  ('affects^response to substance|affects^secretion', 18),
#  ('affects^reaction|decreases^reaction|increases^chemical synthesis', 18),
#  ('decreases^reaction|increases^metabolic processing|increases^reaction', 18),
#  ('decreases^activity|decreases^reaction|increases^response to substance', 18),
#  ('affects^binding|decreases^reaction|increases^abundance|increases^reaction',
#   18),
#  ('affects^reaction|decreases^reaction|increases^reaction|increases^secretion',
#   18),
#  ('decreases^expression|increases^chemical synthesis|increases^oxidation', 18),
#  ('affects^abundance|increases^expression', 18),
#  ('decreases^expression|increases^degradation|increases^reaction', 18),
#  ('decreases^reaction|increases^abundance|increases^response to substance',
#   18),
#  ('affects^reaction|decreases^activity|decreases^phosphorylation', 18),
#  ('affects^cotreatment|decreases^abundance|increases^reaction', 18),
#  ('affects^response to substance|decreases^reaction|increases^cleavage|increases^reaction',
#   18),
#  ('affects^cotreatment|increases^chemical synthesis|increases^expression|increases^reaction',
#   18),
#  ('affects^activity|increases^reaction', 18),
#  ('affects^cotreatment|increases^abundance|increases^activity|increases^phosphorylation',
#   18),
#  ('affects^reaction|increases^abundance|increases^phosphorylation', 18),
#  ('affects^binding|decreases^reaction|increases^uptake', 18),
#  ('decreases^reaction|increases^abundance|increases^expression|increases^reaction',
#   18),
#  ('affects^activity|decreases^reaction|increases^activity', 18),
#  ('decreases^activity|decreases^response to substance|increases^secretion',
#   18),
#  ('affects^cotreatment|affects^reaction|increases^chemical synthesis|increases^reaction',
#   18),
#  ('affects^binding|affects^folding|decreases^activity', 17),
#  ('affects^cotreatment|increases^stability', 17),
#  ('increases^chemical synthesis|increases^reaction|increases^reduction', 17),
#  ('affects^cotreatment|increases^reaction|increases^transport', 17),
#  ('decreases^reaction|increases^reaction|increases^response to substance', 17),
#  ('affects^localization|decreases^phosphorylation|decreases^reaction', 17),
#  ('affects^binding|increases^activity|increases^uptake', 17),
#  ('affects^sulfation', 17),
#  ('decreases^reaction|increases^nitrosation', 17),
#  ('affects^chemical synthesis|increases^reaction', 17),
#  ('affects^cotreatment|affects^reaction|affects^response to substance', 17),
#  ('affects^binding|increases^chemical synthesis|increases^metabolic processing',
#   17),
#  ('increases^response to substance|increases^uptake', 17),
#  ('affects^abundance|increases^reaction', 17),
#  ('affects^response to substance|increases^reaction', 17),
#  ('decreases^hydroxylation|decreases^reaction', 17),
#  ('affects^cotreatment|affects^reaction|decreases^reaction|increases^activity',
#   17),
#  ('affects^cleavage|decreases^reaction', 17),
#  ('affects^localization|increases^uptake', 17),
#  ('decreases^activity|increases^abundance|increases^reaction', 17),
#  ('affects^expression|decreases^response to substance', 17),
#  ('decreases^amination|decreases^reaction', 17),
#  ('affects^binding|increases^activity|increases^reaction|increases^secretion',
#   16),
#  ('affects^binding|decreases^reaction|increases^activity|increases^hydrolysis',
#   16),
#  ('affects^binding|decreases^reaction|increases^localization', 16),
#  ('decreases^reaction|decreases^response to substance|increases^cleavage', 16),
#  ('increases^activity|increases^expression|increases^secretion', 16),
#  ('affects^cotreatment|affects^sulfation', 16),
#  ('affects^localization|decreases^expression|decreases^reaction|increases^reaction',
#   16),
#  ('increases^mutagenesis|increases^response to substance', 16),
#  ('decreases^reduction', 16),
#  ('affects^binding|affects^localization|increases^activity', 16),
#  ('decreases^activity|increases^chemical synthesis', 16),
#  ('affects^activity|affects^cotreatment|affects^reaction', 16),
#  ('affects^localization|decreases^activity|decreases^expression', 16),
#  ('affects^binding|increases^reduction', 16),
#  ('affects^localization|decreases^reaction|increases^activity|increases^phosphorylation',
#   16),
#  ('affects^abundance|affects^expression', 16),
#  ('affects^binding|affects^expression|decreases^reaction', 16),
#  ('affects^binding|affects^cotreatment|decreases^activity|decreases^response to substance',
#   16),
#  ('affects^binding|decreases^expression|increases^response to substance', 16),
#  ('decreases^expression|increases^activity|increases^reaction', 16),
#  ('affects^expression|decreases^reaction|increases^reaction', 16),
#  ('affects^activity|increases^activity', 16),
#  ('decreases^localization|decreases^reaction|increases^phosphorylation', 16),
#  ('affects^cotreatment|decreases^reaction|increases^abundance|increases^activity|increases^phosphorylation',
#   16),
#  ('affects^cotreatment|decreases^response to substance|increases^expression',
#   15),
#  ('decreases^reaction|increases^phosphorylation|increases^response to substance',
#   15),
#  ('affects^cotreatment|affects^expression|increases^reaction', 15),
#  ('decreases^reaction|increases^degradation|increases^ubiquitination', 15),
#  ('affects^localization|increases^activity|increases^cleavage', 15),
#  ('affects^splicing|decreases^reaction', 15),
#  ('affects^expression|affects^secretion', 15),
#  ('affects^reaction|decreases^activity|decreases^reaction', 15),
#  ('affects^cotreatment|decreases^reaction|decreases^stability', 15),
#  ('affects^binding|decreases^phosphorylation|increases^reaction', 15),
#  ('affects^binding|affects^cotreatment|increases^secretion', 15),
#  ('affects^binding|decreases^activity|decreases^export', 15),
#  ('decreases^reaction|increases^response to substance|increases^secretion',
#   15),
#  ('affects^abundance|decreases^activity', 15),
#  ('decreases^phosphorylation|increases^abundance', 15),
#  ('affects^cotreatment|affects^localization|decreases^reaction|increases^phosphorylation',
#   15),
#  ('affects^expression|decreases^activity|increases^expression', 15),
#  ('affects^abundance|affects^binding|increases^activity', 15),
#  ('decreases^reaction|decreases^response to substance|increases^chemical synthesis',
#   15),
#  ('decreases^abundance|decreases^reaction|increases^phosphorylation', 15),
#  ('affects^cotreatment|decreases^reaction|increases^abundance|increases^phosphorylation',
#   15),
#  ('decreases^activity|decreases^expression|decreases^phosphorylation', 15),
#  ('decreases^activity|decreases^export|decreases^reaction|increases^abundance',
#   15),
#  ('affects^binding|affects^reaction|decreases^chemical synthesis|increases^activity',
#   15),
#  ('increases^activity|increases^localization|increases^phosphorylation', 15),
#  ('affects^cotreatment|increases^activity|increases^glutathionylation', 15),
#  ('affects^cotreatment|decreases^reaction|increases^chemical synthesis|increases^reduction',
#   14),
#  ('affects^cotreatment|affects^reaction|increases^reaction|increases^secretion',
#   14),
#  ('increases^expression|increases^import', 14),
#  ('decreases^reaction|increases^activity|increases^uptake', 14),
#  ('decreases^reaction|decreases^ubiquitination|increases^expression', 14),
#  ('affects^cotreatment|affects^localization|increases^activity', 14),
#  ('affects^cotreatment|decreases^reaction|increases^expression|increases^phosphorylation|increases^reaction',
#   14),
#  ('affects^cotreatment|affects^expression|affects^localization', 14),
#  ('affects^binding|increases^oxidation|increases^reaction', 14),
#  ('affects^response to substance|decreases^abundance', 14),
#  ('affects^cotreatment|decreases^activity|decreases^expression', 14),
#  ('decreases^activity|decreases^hydroxylation', 14),
#  ('decreases^abundance|increases^response to substance', 14),
#  ('affects^binding|decreases^phosphorylation', 14),
#  ('affects^cotreatment|affects^reaction|increases^response to substance', 14),
#  ('decreases^expression|decreases^reaction|increases^response to substance',
#   14),
#  ('affects^cotreatment|decreases^reaction|increases^activity|increases^secretion',
#   14),
#  ('increases^cleavage|increases^reaction|increases^response to substance', 14),
#  ('affects^reaction|affects^response to substance|decreases^reaction', 14),
#  ('decreases^abundance|decreases^activity|decreases^expression', 14),
#  ('decreases^expression|decreases^localization', 14),
#  ('increases^abundance|increases^activity|increases^response to substance',
#   14),
#  ('affects^expression|affects^methylation', 14),
#  ('affects^metabolic processing|decreases^expression', 14),
#  ('affects^binding|affects^localization|increases^expression|increases^reaction',
#   14),
#  ('affects^binding|affects^cotreatment|increases^abundance', 14),
#  ('increases^localization|increases^phosphorylation', 14),
#  ('affects^response to substance|increases^cleavage', 14),
#  ('increases^abundance|increases^activity|increases^localization', 14),
#  ('affects^cotreatment|affects^reaction|increases^transport', 14),
#  ('affects^binding|increases^activity|increases^import', 14),
#  ('increases^alkylation', 14),
#  ('affects^cleavage|affects^response to substance', 14),
#  ('decreases^activity|decreases^reaction|increases^acetylation', 14),
#  ('affects^binding|decreases^activity|decreases^reaction|increases^response to substance',
#   14),
#  ('affects^cotreatment|decreases^reaction|increases^activity|increases^chemical synthesis|increases^cleavage',
#   14),
#  ('affects^response to substance|increases^expression|increases^reaction', 14),
#  ('decreases^reaction|decreases^response to substance|increases^expression|increases^reaction',
#   14),
#  ('affects^cotreatment|decreases^phosphorylation|decreases^response to substance',
#   14),
#  ('affects^cotreatment|affects^reaction|increases^activity|increases^cleavage',
#   14),
#  ('affects^reaction|decreases^reaction|increases^expression|increases^reaction',
#   14),
#  ('decreases^reaction|decreases^response to substance|increases^phosphorylation',
#   13),
#  ('decreases^reaction|increases^import|increases^reaction', 13),
#  ('affects^binding|decreases^activity|increases^abundance', 13),
#  ('decreases^degradation|increases^reaction', 13),
#  ('affects^binding|decreases^activity|decreases^reaction|decreases^response to substance',
#   13),
#  ('affects^reaction|decreases^transport', 13),
#  ('decreases^ethylation', 13),
#  ('affects^cotreatment|decreases^activity|increases^expression', 13),
#  ('decreases^activity|increases^mutagenesis', 13),
#  ('decreases^activity|increases^expression|increases^phosphorylation', 13),
#  ('increases^activity|increases^stability', 13),
#  ('affects^transport|decreases^reaction|increases^reaction', 13),
#  ('decreases^lipidation', 13),
#  ('decreases^expression|increases^cleavage', 13),
#  ('decreases^abundance|increases^secretion', 13),
#  ('affects^binding|decreases^reaction|increases^activity|increases^chemical synthesis',
#   13),
#  ('affects^binding|increases^abundance|increases^activity|increases^reaction',
#   13),
#  ('decreases^response to substance|increases^abundance', 13),
#  ('decreases^methylation|decreases^reaction|increases^expression', 13),
#  ('affects^binding|affects^cotreatment|decreases^reaction|increases^abundance',
#   13),
#  ('decreases^reaction|increases^response to substance|increases^uptake', 13),
#  ('affects^cotreatment|decreases^response to substance|increases^activity',
#   13),
#  ('affects^cotreatment|decreases^abundance|increases^expression', 13),
#  ('affects^binding|increases^reaction|increases^response to substance', 13),
#  ('affects^binding|decreases^activity|increases^response to substance', 13),
#  ('increases^activity|increases^chemical synthesis|increases^reaction', 13),
#  ('increases^abundance|increases^expression|increases^secretion', 13),
#  ('decreases^activity|decreases^hydrolysis', 13),
#  ('decreases^expression|increases^abundance|increases^expression', 13),
#  ('affects^cotreatment|increases^chemical synthesis|increases^reduction', 12),
#  ('affects^binding|increases^activity|increases^localization', 12),
#  ('decreases^expression|decreases^reaction|increases^abundance|increases^activity',
#   12),
#  ('affects^cotreatment|decreases^expression|decreases^reaction|decreases^secretion',
#   12),
#  ('affects^export|increases^reaction', 12),
#  ('decreases^activity|decreases^chemical synthesis|decreases^metabolic processing',
#   12),
#  ('affects^reaction|decreases^activity|decreases^reaction|increases^cleavage',
#   12),
#  ('affects^binding|decreases^reaction|increases^hydroxylation', 12),
#  ('affects^binding|decreases^phosphorylation|decreases^reaction', 12),
#  ('affects^localization|decreases^expression|increases^reaction', 12),
#  ('affects^cotreatment|decreases^expression|increases^expression|increases^phosphorylation',
#   12),
#  ('affects^cotreatment|decreases^expression|increases^expression|increases^reaction',
#   12),
#  ('affects^binding|decreases^activity|decreases^reaction|increases^reaction|increases^secretion',
#   12),
#  ('decreases^amination', 12),
#  ('affects^expression|decreases^activity', 12),
#  ('affects^chemical synthesis|decreases^reaction', 12),
#  ('affects^cotreatment|decreases^expression|increases^secretion', 12),
#  ('affects^binding|decreases^secretion', 12),
#  ('decreases^reaction|decreases^transport', 12),
#  ('affects^expression|affects^localization|decreases^reaction', 12),
#  ('affects^cotreatment|decreases^activity|decreases^reaction|increases^chemical synthesis',
#   12),
#  ('decreases^activity|increases^expression|increases^reaction', 12),
#  ('affects^localization|affects^reaction|increases^phosphorylation', 12),
#  ('increases^lipidation', 12),
#  ('affects^reaction|decreases^phosphorylation|increases^expression', 12),
#  ('affects^expression|affects^reaction|affects^secretion', 12),
#  ('affects^binding|decreases^reaction|increases^acylation|increases^secretion',
#   12),
#  ('affects^activity|affects^binding|affects^cotreatment', 12),
#  ('affects^cotreatment|increases^activity|increases^reduction', 12),
#  ('decreases^reaction|increases^abundance|increases^activity|increases^cleavage',
#   12),
#  ('affects^binding|affects^cotreatment|increases^activity|increases^stability',
#   12),
#  ('affects^binding|affects^cotreatment|affects^reaction|increases^activity|increases^stability',
#   12),
#  ('increases^expression|increases^localization|increases^reaction', 12),
#  ('affects^metabolic processing|decreases^activity|decreases^reaction', 12),
#  ('increases^activity|increases^hydrolysis', 12),
#  ('affects^cotreatment|decreases^activity|decreases^reaction|increases^abundance',
#   12),
#  ('affects^activity|decreases^response to substance', 12),
#  ('decreases^reaction|increases^acetylation|increases^expression', 12),
#  ('affects^binding|decreases^reaction|increases^abundance|increases^expression',
#   12),
#  ('affects^response to substance|affects^uptake', 12),
#  ('affects^reaction|increases^expression|increases^phosphorylation', 12),
#  ('affects^cotreatment|decreases^reaction|increases^hydrolysis', 12),
#  ('affects^cleavage|affects^reaction', 12),
#  ('increases^abundance|increases^hydrolysis', 12),
#  ('affects^cotreatment|increases^activity|increases^reaction|increases^transport',
#   12),
#  ('affects^cotreatment|decreases^reaction|increases^degradation|increases^reaction',
#   12),
#  ('affects^cotreatment|decreases^reaction|increases^acetylation', 12),
#  ('increases^activity|increases^cleavage|increases^response to substance', 12),
#  ('decreases^expression|decreases^reaction|increases^metabolic processing',
#   12),
#  ('affects^activity|affects^reaction|affects^response to substance|increases^abundance',
#   12),
#  ('affects^cotreatment|increases^activity|increases^methylation', 12),
#  ('affects^binding|affects^cotreatment|decreases^reaction|increases^expression|increases^reaction',
#   12),
#  ('affects^abundance|affects^chemical synthesis|increases^reaction', 12),
#  ('affects^cotreatment|affects^secretion|decreases^reaction', 12),
#  ('increases^response to substance|increases^transport', 12),
#  ('affects^import', 12),
#  ('increases^expression|increases^reaction|increases^stability', 12),
#  ('affects^localization|affects^reaction|increases^activity', 12),
#  ('decreases^activity|decreases^reaction|increases^oxidation', 12),
#  ('increases^abundance|increases^chemical synthesis|increases^oxidation|increases^reaction',
#   12),
#  ...]

# %%
submeta_file = 'raw_data/sub_metadata.csv'
submeta_df = pd.read_csv(submeta_file)
submeta_df = submeta_df.astype({'pubmed_id': 'int'})

# %%
submeta_df.pubmed_id
# Out:
# 0         4579077
# 1         2861742
# 2         3052052
# 3         3048091
# 4         1621745
#            ...
# 26473    29246869
# 26474    32104726
# 26475    27421627
# 26476    26806161
# 26477    24121017
# Name: pubmed_id, Length: 26478, dtype: int64

# %%
gene_file = 'raw_data/KG/Genes.csv'
gene_df = pd.read_csv(gene_file, delimiter='\t')
gene_df = gene_df.fillna('')
gene_df
# Out:
#                GeneSymbol                                           GeneName  \
# 0                  03B03F            DNA segment, 03B03F (Research Genetics)
# 1                  03B03R            DNA segment, 03B03R (Research Genetics)
# 2       03.MMHAP34FRA.SEQ                     DNA segment, 03.MMHAP34FRA.seq
# 3                   064YA
# 4                 102G4T7                               DNA segment, 102g4T7
# ...                   ...                                                ...
# 521636            ZZEF1.S  zinc finger, ZZ-type with EF-hand domain 1 S h...
# 521637              ZZZ-1     G_PROTEIN_RECEP_F1_2 domain-containing protein
# 521638               ZZZ3                   zinc finger ZZ-type containing 3
# 521639             ZZZ3.L       zinc finger, ZZ-type containing 3 L homeolog
# 521640             ZZZ3.S       zinc finger, ZZ-type containing 3 S homeolog
#
#            GeneID                                         AltGeneIDs
# 0           27777
# 1           27778
# 2           53288
# 3         5658107
# 4           56573
# ...           ...                                                ...
# 521636  108709661
# 521637     185208
# 521638      26009  100053222|100074855|100227013|100343576|100379...
# 521639  108714197
# 521640  108715504
#
# [521641 rows x 4 columns]

# %%
chem_file = 'raw_data/KG/diseases.csv'
chem_df = pd.read_csv(chem_file, delimiter='\t')
chem_df
# Out:
#                                   ChemicalName    ChemicalID  \
# 0                      (0.017ferrocene)amylose  MESH:C089250
# 1                                   001-C8-NBD  MESH:C114385
# 2                          001-C8 oligopeptide  MESH:C114386
# 3                         0231A , Streptomyces  MESH:C434150
# 4                          0231B, Streptomyces  MESH:C434149
# ...                                        ...           ...
# 173253  (Z,Z)-5-(trideca-4,7-dienyl)resorcinol  MESH:C568787
# 173254           (Z,Z)-6,9-heneicosadien-11-ol  MESH:C482761
# 173255               (Z,Z)-7,11-hexadecadienal  MESH:C558532
# 173256              (Z,Z)-dodeca-3,6-dien-1-ol  MESH:C483463
# 173257         (Z,Z,E)-7,11,13-hexadecatrienal  MESH:C558533
#
#                                         ParentIDs
# 0       MESH:D000075163|MESH:D000688|MESH:D005296
# 1                       MESH:D009842|MESH:D010069
# 2                                    MESH:D009842
# 3                                    MESH:D006576
# 4                                    MESH:D006576
# ...                                           ...
# 173253                               MESH:D012118
# 173254                               MESH:D000466
# 173255                  MESH:D000466|MESH:D012724
# 173256                  MESH:D000466|MESH:D010675
# 173257                  MESH:D011090|MESH:D012724
#
# [173258 rows x 3 columns]

# %%
dis_file = 'raw_data/KG/diseases.csv'
dis_df = pd.read_csv(dis_file, delimiter='\t')
dis_df
# Out:
#                             DiseaseName     DiseaseID  \
# 0       10p Deletion Syndrome (Partial)  MESH:C538288
# 1                 13q deletion syndrome  MESH:C535484
# 2                   15q24 Microdeletion  MESH:C579849
# 3             16p11.2 Deletion Syndrome  MESH:C579850
# 4      17,20-Lyase Deficiency, Isolated  MESH:C567076
# ...                                 ...           ...
# 13054   Zunich neuroectodermal syndrome  MESH:C536729
# 13055                   Zuska's Disease  MESH:C536730
# 13056                     Zygodactyly 1  MESH:C565223
# 13057               Zygomatic Fractures  MESH:D015051
# 13058                       Zygomycosis  MESH:D020096
#
#                                            AltDiseaseIDs  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 13054                                                NaN
# 13055                                                NaN
# 13056                                                NaN
# 13057                           Fractures of the zygoma.
# 13058  Infection in humans and animals caused by fung...
#
#                                                ParentIDs
# 0                              MESH:D002872|MESH:D025063
# 1                              MESH:D002872|MESH:D025063
# 2                 MESH:D002872|MESH:D008607|MESH:D025063
# 3      MESH:D001321|MESH:D002872|MESH:D008607|MESH:D0...
# 4                                           MESH:D000312
# ...                                                  ...
# 13054  MESH:D003103|MESH:D006314|MESH:D006330|MESH:D0...
# 13055             MESH:D000038|MESH:D001941|MESH:D005402
# 13056                                       MESH:D013576
# 13057                          MESH:D008446|MESH:D012887
# 13058                                       MESH:D009181
#
# [13059 rows x 4 columns]
